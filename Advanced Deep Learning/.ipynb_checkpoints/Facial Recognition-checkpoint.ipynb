# %% [markdown]
# # PG AI - Advanced Deep Learning and Computer Vision

# %% [markdown]
# ### Facial Recognition with Deep Learning in Keras Using CNN

# %% [markdown]
# #### Problem Statement:
# Facial recognition is a biometric alternative that measures unique characteristics of a human face. Applications available today include flight check in, tagging friends and family members in photos, and “tailored” advertising. You are a computer vision engineer who needs to develop a face recognition programme with deep convolutional neural networks.

# %% [markdown]
# #### Dataset Details:
# ORL face database composed of 400 images of size 112 x 92. There are 20 people, 20 images per person. The images were taken at different times, lighting and facial expressions. The faces are in an upright position in frontal view, with a slight left-right rotation.

# %% [markdown]
# #### Importing required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
# Out:
# Using TensorFlow backend.

# %%
keras.__version__
# Out:
# '2.3.1'

# %% [markdown]
# #### Loading the dataset

# %%
data =  np.load('ORL_faces.npz')
data

# %% [markdown]
# #### Exploring the files in the dataset

# %%
files = [file for file in data.files]
files
# Out:
# ['testY', 'testX', 'trainX', 'trainY']

# %% [markdown]
# #### Splitting the dataset in Training and Test

# %%
X_train, y_train, X_test, y_test = data['trainX'], data['trainY'], data['testX'], data['testY']
print("Training: {}".format((X_train.shape,y_train.shape)))
print("Test: {}".format((X_test.shape,y_test.shape)))
# Out:
# Training: ((240, 10304), (240,))
# Test: ((160, 10304), (160,))

# %% [markdown]
# #### Identifying the unique class labels for classification

# %%
len(np.unique(y_test))
# Out:
# 20

# %% [markdown]
# #### EDA: To find the imbalance in the class labels
#
# _The class labels are uniformly represented, hence there is no imbalance in the datase._

# %%
df = np.unique(y_train, return_counts=True)
df = pd.DataFrame({'class': df[0], 'count': df[1]})
df.plot(kind='bar', x='class', y=['count'])

# %% [markdown]
# #### EDA: Sampling Random Images from the Training set

# %%
samples = np.random.randint(low=0, high=len(X_train)-1, size=3)

fig, axs = plt.subplots(1,3)
for ax, sample in zip(axs,samples):
    ax.imshow(X_train[sample].reshape(112,92))
    ax.set_title('Image No. {}\n Class No. {}'.format(sample, y_train[sample]), 
                 fontdict={'size': 8})
    ax.axis('off')

plt.show()

# %% [markdown]
# #### Normalizing/Scaling Images between 0 and 1

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# #### Creating image shape to feed in the CNN

# %%
img_wt = 112
img_ht = 92

img_shape = (img_wt, img_ht, 1)

# %% [markdown]
# #### Importing required libraries to create the Neural Network with CNN and ANN

# %%
from keras.models import Sequential 
from keras.layers import Conv2D, MaxPooling2D 
from keras.layers import Activation, Dropout, Flatten, Dense

# %% [markdown]
# #### Model Architechture:
# 1. Keras Sequential
# 2. Conv2D->MaxPool => 2 Layers
# 3. Flatten Layer
# 4. Hidden Dense Layer => 1 layer
# 5. Output Layer (Softmax)

# %%
model = Sequential() 
model.add(Conv2D(32, (2, 2), input_shape=img_shape)) 
model.add(Activation('relu')) 
model.add(MaxPooling2D(pool_size=(2, 2))) 

model.add(Conv2D(64, (2, 2))) 
model.add(Activation('relu')) 
model.add(MaxPooling2D(pool_size=(2, 2))) 
  
model.add(Conv2D(128, (2, 2))) 
model.add(Activation('relu')) 
model.add(MaxPooling2D(pool_size=(2, 2))) 
  
model.add(Flatten()) 
model.add(Dense(128)) 
model.add(Activation('relu')) 
model.add(Dropout(0.2)) 
model.add(Dense(20)) 
model.add(Activation('softmax'))

# %% [markdown]
# #### Model summary

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 108, 88, 128)      3328
# _________________________________________________________________
# activation_1 (Activation)    (None, 108, 88, 128)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 21, 17, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 19, 15, 64)        73792
# _________________________________________________________________
# activation_2 (Activation)    (None, 19, 15, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 5, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 5, 4, 32)          8224
# _________________________________________________________________
# activation_3 (Activation)    (None, 5, 4, 32)          0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# activation_4 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                2580
# _________________________________________________________________
# activation_5 (Activation)    (None, 20)                0
# =================================================================
# Total params: 104,436
# Trainable params: 104,436
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Reshaping the Training and Test dataset to feed in the Network

# %%
X_train = X_train.reshape(240,112,92,1)
X_test = X_test.reshape(160,112,92,1)

# %% [markdown]
# #### Model Training
# 1. Optimiser: Adam
# 2. Loss: Sparse Categorical Cross Entropy
# 3. Metrics: Accuracy
# 4. Epochs: 25
# 5. Batch Size: 16

# %%
epochs = 25
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history = model.fit(X_train, y_train, validation_data = (X_test, y_test), 
                     epochs=epochs, batch_size=16)
# Out:
# Train on 240 samples, validate on 160 samples
# Epoch 1/25
# 240/240 [==============================] - 2s 9ms/step - loss: 0.6171 - accuracy: 0.7792 - val_loss: 1.0189 - val_accuracy: 0.7188
# Epoch 2/25
# 240/240 [==============================] - 2s 9ms/step - loss: 0.4952 - accuracy: 0.8375 - val_loss: 0.8684 - val_accuracy: 0.8250
# Epoch 3/25
# 240/240 [==============================] - 2s 9ms/step - loss: 0.4081 - accuracy: 0.8750 - val_loss: 0.9274 - val_accuracy: 0.8062
# Epoch 4/25
# 240/240 [==============================] - 2s 9ms/step - loss: 0.3926 - accuracy: 0.8708 - val_loss: 0.7950 - val_accuracy: 0.8125
# Epoch 5/25
# 240/240 [==============================] - 2s 9ms/step - loss: 0.3495 - accuracy: 0.8833 - val_loss: 0.7898 - val_accuracy: 0.8313
# Epoch 6/25
# 240/240 [==============================] - 2s 9ms/step - loss: 0.3285 - accuracy: 0.8625 - val_loss: 0.7686 - val_accuracy: 0.8375
# Epoch 7/25
# 240/240 [==============================] - 2s 9ms/step - loss: 0.2881 - accuracy: 0.9083 - val_loss: 0.7939 - val_accuracy: 0.8375
# Epoch 8/25
# 240/240 [==============================] - 2s 9ms/step - loss: 0.3886 - accuracy: 0.8667 - val_loss: 0.7381 - val_accuracy: 0.8562
# Epoch 9/25
# 240/240 [==============================] - 2s 9ms/step - loss: 0.3582 - accuracy: 0.8750 - val_loss: 0.7454 - val_accuracy: 0.8625
# Epoch 10/25
# 240/240 [==============================] - 2s 9ms/step - loss: 0.2066 - accuracy: 0.9500 - val_loss: 0.7521 - val_accuracy: 0.8438
# Epoch 11/25
# 240/240 [==============================] - 2s 9ms/step - loss: 0.1947 - accuracy: 0.9458 - val_loss: 0.9077 - val_accuracy: 0.8000
# Epoch 12/25
# 240/240 [==============================] - 2s 9ms/step - loss: 0.2870 - accuracy: 0.8792 - val_loss: 0.6901 - val_accuracy: 0.8500
# Epoch 13/25
# 240/240 [==============================] - 2s 9ms/step - loss: 0.2524 - accuracy: 0.9250 - val_loss: 0.6929 - val_accuracy: 0.8687
# Epoch 14/25
# 240/240 [==============================] - 2s 10ms/step - loss: 0.2313 - accuracy: 0.9208 - val_loss: 0.6565 - val_accuracy: 0.8562
# Epoch 15/25
# 240/240 [==============================] - 2s 10ms/step - loss: 0.1826 - accuracy: 0.9417 - val_loss: 0.7874 - val_accuracy: 0.8500
# Epoch 16/25
# 240/240 [==============================] - 2s 9ms/step - loss: 0.2015 - accuracy: 0.9500 - val_loss: 0.7420 - val_accuracy: 0.8562
# Epoch 17/25
# 240/240 [==============================] - 2s 9ms/step - loss: 0.1351 - accuracy: 0.9542 - val_loss: 0.8151 - val_accuracy: 0.8250
# Epoch 18/25
# 240/240 [==============================] - 2s 9ms/step - loss: 0.2000 - accuracy: 0.9417 - val_loss: 0.9116 - val_accuracy: 0.8562
# Epoch 19/25
# 240/240 [==============================] - 2s 9ms/step - loss: 0.1149 - accuracy: 0.9708 - val_loss: 0.8150 - val_accuracy: 0.8188
# Epoch 20/25
# 240/240 [==============================] - 2s 9ms/step - loss: 0.1540 - accuracy: 0.9583 - val_loss: 0.8096 - val_accuracy: 0.8313
# Epoch 21/25
# 240/240 [==============================] - 2s 9ms/step - loss: 0.1384 - accuracy: 0.9500 - val_loss: 0.7956 - val_accuracy: 0.8375
# Epoch 22/25
# 240/240 [==============================] - 2s 9ms/step - loss: 0.1502 - accuracy: 0.9583 - val_loss: 0.7881 - val_accuracy: 0.8375
# Epoch 23/25
# 240/240 [==============================] - 2s 9ms/step - loss: 0.1312 - accuracy: 0.9500 - val_loss: 0.6735 - val_accuracy: 0.8687
# Epoch 24/25
# 240/240 [==============================] - 2s 9ms/step - loss: 0.1075 - accuracy: 0.9792 - val_loss: 0.7313 - val_accuracy: 0.8500
# Epoch 25/25
# 240/240 [==============================] - 2s 9ms/step - loss: 0.0832 - accuracy: 0.9667 - val_loss: 0.7480 - val_accuracy: 0.8313

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# #### Model Evaluation

# %%
model.evaluate(x=X_test,y=y_test)

# %% [markdown]
# #### Testing Model predictions with random images

# %%
samples = np.random.randint(low=0, high=len(X_test)-1, size=3)
X_new = X_test[samples]
y_new = y_test[samples]
preds = model.predict(x=X_new)

fig, axs = plt.subplots(1,3)
for index, ax in enumerate(axs):
    ax.imshow(X_new[index].reshape(112,92))
    ax.set_title('Actual Class No. {}\n Predicted Class No. {}\n'.
                 format(y_new[index], np.argmax(preds[index])), 
                 fontdict={'size': 10})
    ax.axis('off')

plt.show()

# %% [markdown]
# #### Saving the the model

# %%
model.save("face_recognition")
